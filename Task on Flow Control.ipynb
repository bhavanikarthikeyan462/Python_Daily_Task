# %% [markdown]
# # 11-July-26

# %% [markdown]
# # Task on Flow Control

# %%
# 1. check whether a number is positive or negative

num = int(input("Enter a number: "))

if num >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number:  25
# Positive

# %%
# 2. check voting eligibility

age = int(input("Enter your age: "))

if age >= 18:
    print("You can vote")
# Out:
# Enter your age:  20
# You can vote

# %%
# 3. find the larger of two numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Larger number:", a)
else:
    print("Larger number:", b)
# Out:
# Enter first number:  25
# Enter second number:  35
# Larger number: 35

# %%
# 4. check even or odd

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  18
# Even

# %%
# 5. check if character is A

ch = input("Enter a character: ")

if ch == 'A':
    print("Character is A")
else:
    print("Character is not A")
# Out:
# Enter a character:  B
# Character is not A

# %%
# 6. check pass or fail

marks = int(input("Enter marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  65
# Pass

# %%
# 7. check if number is divisible by 5

num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Enter a number:  25
# Number is divisible by 5

# %%
# 8. positive, negative, or zero

num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  13
# Positive

# %%
# 9. find the largest of three numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest:", a)
elif b >= a and b >= c:
    print("Largest:", b)
else:
    print("Largest:", c)
# Out:
# Enter first number:  23
# Enter second number:  15
# Enter third number:  34
# Largest: 34

# %%
# 10. check leap year

year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year:  2023
# Not a Leap Year

# %%
# 11. check vowel or consonant

ch = input("Enter a character: ")

if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  sam
# Consonant

# %%
# 12. salary category

salary = float(input("Enter salary: "))

if salary > 50000:
    print("High")
elif salary > 30000:
    print("Medium")
else:
    print("Low")
# Out:
# Enter salary:  90000
# High

# %%
# 13. temperature category

temperature = float(input("Enter temperature in Celsius: "))

if temperature > 30:
    print("Hot")
elif temperature >= 20:
    print("Warm")
else:
    print("Cold")
# Out:
# Enter temperature in Celsius:  35
# Hot

# %%
# 14. username and password category

username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  12365
# Login Failed

# %%
# 15. check traingle validity and type

a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

if a + b > c and a + c > b and b + c > a:
    print("Valid Triangle")

    if a == b == c:
        print("Equilateral")
    elif a == b or b == c or a == c:
        print("Isosceles")
    else:
        print("Scalene")
else:
    print("Invalid Triangle")
# Out:
# Enter first side:  5
# Enter second side:  6
# Enter third side:  3
# Valid Triangle
# Scalene

# %%
# 16.  calculate percentage and grade

m1 = float(input("Enter marks for subject 1: "))
m2 = float(input("Enter marks for subject 2: "))
m3 = float(input("Enter marks for subject 3: "))
m4 = float(input("Enter marks for subject 4: "))
m5 = float(input("Enter marks for subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

print("Total Marks:", total)
print("Percentage:", percentage)

if percentage >= 90:
    print("Grade: A+")
elif percentage >= 80:
    print("Grade: A")
elif percentage >= 70:
    print("Grade: B")
elif percentage >= 60:
    print("Grade: C")
else:
    print("Grade: Fail")
# Out:
# Enter marks for subject 1:  55
# Enter marks for subject 2:  60
# Enter marks for subject 3:  90
# Enter marks for subject 4:  60
# Enter marks for subject 5:  100
# Total Marks: 365.0
# Percentage: 73.0
# Grade: B

# %%
# 17. fizzbuzz

num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
else:
    print(num)
# Out:
# Enter a number:  25
# Buzz

# %%
# 18. check eligibility based on age and gender

age = int(input("Enter age: "))
gender = input("Enter gender: ")

if age >= 18 and gender.lower() == "male":
    print("Eligible for Army")
elif age >= 18 and gender.lower() == "female":
    print("Eligible for Other Services")
else:
    print("Not Eligible")
# Out:
# Enter age:  25
# Enter gender:  60
# Not Eligible

# %%
# 19. check uppercase,lowercase, digit,or special character

ch = input("Enter a character: ")

if ch.isupper():
    print("Uppercase")
elif ch.islower():
    print("Lowercase")
elif ch.isdigit():
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter a character:  mian
# Lowercase

# %%
# 20. print 3 numbers in ascending order without sort()

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a <= b and a <= c:
    if b <= c:
        print("Ascending order:", a, b, c)
    else:
        print("Ascending order:", a, c, b)

elif b <= a and b <= c:
    if a <= c:
        print("Ascending order:", b, a, c)
    else:
        print("Ascending order:", b, c, a)

else:
    if a <= b:
        print("Ascending order:", c, a, b)
    else:
        print("Ascending order:", c, b, a)
# Out:
# Enter first number:  50
# Enter second number:  25
